# %%
import obspy
import obspy.signal.filter
from obspy.io.sac.sactrace import SACTrace
from obspy.io.sac.util import get_sac_reftime
import os
import glob
import numpy as np
import shutil

# %%
os.getcwd()
# Out:
# '/home/youzhi/python-projects/sp-project'

# %%
data_sac = "/home/youzhi/python-projects/sp-project/SAC_for_readin"

for year in sorted(os.listdir(data_sac)):
    print(year)
    inpath = os.path.join(data_sac, year)
    if os.path.isdir(inpath):
        print(inpath)
        os.chdir(inpath)
        for bp in sorted(glob.glob("*.bp")):
            print(bp)
            # calculate the envelope
            tr = obspy.read(bp)
            trenv = obspy.signal.filter.envelope(tr[0].data)
            tr[0].data = trenv
            tr[0].write(bp +".ev", format='SAC')
            
            nbp = "{}.{}".format(bp,"ev")
            ntr = obspy.read(nbp)
            # cut the waveform within a given time window, -2 to 11 s
            # changed to 11 based on data I collected
            T = get_sac_reftime(ntr[0].stats.sac) + 0
            ntr.trim(starttime = T-2, endtime = T+11, fill_value=0)
            ntr[0].write(nbp, format='SAC')

            tr = obspy.read(bp)
            # cut the waveform within a given time window, -2 to 11 s
            T = get_sac_reftime(tr[0].stats.sac) + 0
            tr.trim(starttime = T-2, endtime = T+11, fill_value=0)
            tr[0].write(bp, format='SAC')
# Out:
# 20220112002458770
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220112002458770
# 20220112002458770.CI.HOL.BHZ.SAC.bp
# 20220112021208390
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220112021208390
# 20220112021208390.AZ.LVA2.BHZ.SAC.bp
# 20220112021208390.AZ.SMER.BHZ.SAC.bp
# 20220112021208390.BC.RMX.BHZ.SAC.bp
# 20220112090603170
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220112090603170
# 20220112090603170.CI.EML.BHZ.SAC.bp
# 20220113032108850
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220113032108850
# 20220113032108850.CI.CSH.BHZ.SAC.bp
# 20220113032453520
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220113032453520
# 20220113032453520.CI.NSS2.BHZ.SAC.bp
# 20220113032453520.CI.RHR.BHZ.SAC.bp
# 20220113032453520.CI.SWS.BHZ.SAC.bp
# 20220113082309790
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220113082309790
# 20220113082309790.CI.DPP.BHZ.SAC.bp
# 20220113082309790.CI.HMT2.BHZ.SAC.bp
# 20220113082309790.CI.MGE.BHZ.SAC.bp
# 20220113082309790.CI.MUR.BHZ.SAC.bp
# 20220113082309790.CI.PER.BHZ.SAC.bp
# 20220113082309790.CI.TOR.BHZ.SAC.bp
# 20220115161902000
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220115161902000
# 20220115161902000.CI.FDR.BHZ.SAC.bp
# 20220115161902000.CI.TEH.BHZ.SAC.bp
# 20220116091814410
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220116091814410
# 20220116091814410.BC.RMX.BHZ.SAC.bp
# 20220116091814410.CI.ERR.BHZ.SAC.bp
# 20220116091814410.CI.IMP.BHZ.SAC.bp
# 20220116124930000
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220116124930000
# 20220116124930000.CI.CCA.BHZ.SAC.bp
# 20220116124930000.CI.CCC.BHZ.SAC.bp
# 20220116124930000.CI.LMR2.BHZ.SAC.bp
# 20220116124930000.CI.SRT.BHZ.SAC.bp
# 20220116124930000.CI.TEH.BHZ.SAC.bp
# 20220116145950590
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220116145950590
# 20220116145950590.CI.CCC.BHZ.SAC.bp
# 20220116145950590.CI.SRT.BHZ.SAC.bp
# 20220116145950590.CI.TEH.BHZ.SAC.bp
# 20220116145950590.CI.WOR.BHZ.SAC.bp
# 20220116145950590.NN.GWY.BHZ.SAC.bp
# 20220116145950590.PB.B921.BHZ.SAC.bp
# 20220117000229990
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220117000229990
# 20220117000229990.CI.FOX2.BHZ.SAC.bp
# 20220117000229990.CI.HRV.BHZ.SAC.bp
# 20220117000229990.CI.NCH.BHZ.SAC.bp
# 20220117155620910
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220117155620910
# 20220117155620910.CI.CWP.BHZ.SAC.bp
# 20220117155620910.CI.JNH2.BHZ.SAC.bp
# 20220117155620910.CI.PASC00.BHZ.SAC.bp
# 20220117155620910.CI.PLS.BHZ.SAC.bp
# 20220117155620910.CI.RKMO.BHZ.SAC.bp
# 20220118073915120
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220118073915120
# 20220118073915120.CI.BOR.BHZ.SAC.bp
# 20220118073915120.CI.LMS.BHZ.SAC.bp
# 20220118073915120.CI.LUG.BHZ.SAC.bp
# 20220118073915120.CI.NSS2.BHZ.SAC.bp
# 20220118073915120.CI.SLH.BHZ.SAC.bp
# 20220118073915120.CI.THM.BHZ.SAC.bp
# 20220118073915120.CI.VTV.BHZ.SAC.bp
# 20220118084437210
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220118084437210
# 20220118084437210.CI.BOR.BHZ.SAC.bp
# 20220120095230400
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220120095230400
# 20220120095230400.CI.SLA.BHZ.SAC.bp
# 20220120095230400.PB.B918.BHZ.SAC.bp
# 20220122010142300
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220122010142300
# 20220122010142300.CI.SLB.BHZ.SAC.bp
# 20220122234305360
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220122234305360
# 20220122234305360.CI.DTP.BHZ.SAC.bp
# 20220122234305360.CI.FDR.BHZ.SAC.bp
# 20220123044939870
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220123044939870
# 20220123044939870.CI.TFT.BHZ.SAC.bp
# 20220123205715240
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220123205715240
# 20220123205715240.AZ.RDM.BHZ.SAC.bp
# 20220123205715240.CI.IDO.BHZ.SAC.bp
# 20220124023838010
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220124023838010
# 20220124023838010.CI.CRR.BHZ.SAC.bp
# 20220124023838010.CI.RUN.BHZ.SAC.bp
# 20220125172319330
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220125172319330
# 20220125172319330.CI.CHR.BHZ.SAC.bp
# 20220125192818690
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220125192818690
# 20220125192818690.CI.WMF.BHZ.SAC.bp
# 20220125212130440
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220125212130440
# 20220125212130440.CI.CHR.BHZ.SAC.bp
# 20220125212130440.CI.MPI.BHZ.SAC.bp
# 20220126050555330
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220126050555330
# 20220126050555330.CI.CGO.BHZ.SAC.bp
# 20220126095905010
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220126095905010
# 20220126095905010.CI.CCA.BHZ.SAC.bp
# 20220126103830020
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220126103830020
# 20220126103830020.CI.WAS2.BHZ.SAC.bp
# 20220127033401460
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220127033401460
# 20220127033401460.CI.CCA.BHZ.SAC.bp
# 20220127095426310
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220127095426310
# 20220127095426310.CI.LMR2.BHZ.SAC.bp
# 20220128104007860
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220128104007860
# 20220128104007860.CI.CWP.BHZ.SAC.bp
# 20220128203303970
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220128203303970
# 20220128203303970.CI.WAS2.BHZ.SAC.bp
# 20220129055641000
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220129055641000
# 20220129055641000.CI.OSI.BHZ.SAC.bp
# 20220129055641000.CI.TER2.BHZ.SAC.bp
# 20220131234528720
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220131234528720
# 20220131234528720.AZ.LVA2.BHZ.SAC.bp
# 20220131234528720.CI.CWP.BHZ.SAC.bp
# 20220201012424220
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220201012424220
# 20220201012424220.CI.SLV.BHZ.SAC.bp
# 20220201012424220.CI.SWP.BHZ.SAC.bp
# 20220201192630930
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220201192630930
# 20220201192630930.CI.RUN.BHZ.SAC.bp
# 20220202070130500
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220202070130500
# 20220202070130500.CI.FRK.BHZ.SAC.bp
# 20220202100105740
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220202100105740
# 20220202100105740.CI.FRK.BHZ.SAC.bp
# 20220202100105740.CI.WWC.BHZ.SAC.bp
# 20220203075810850
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220203075810850
# 20220203075810850.CI.SBB2.BHZ.SAC.bp
# 20220203151832540
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220203151832540
# 20220203151832540.CI.CWP.BHZ.SAC.bp
# 20220203170822680
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220203170822680
# 20220203170822680.CI.DTP.BHZ.SAC.bp
# 20220204105219770
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220204105219770
# 20220204105219770.CI.CWP.BHZ.SAC.bp
# 20220204105219770.CI.RKMO.BHZ.SAC.bp
# 20220205074104630
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220205074104630
# 20220205074104630.CI.SDG.BHZ.SAC.bp
# 20220205074909660
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220205074909660
# 20220205074909660.CI.HAY.BHZ.SAC.bp
# 20220205074909660.CI.YUH2.BHZ.SAC.bp
# 20220205183420810
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220205183420810
# 20220205183420810.CI.SLH.BHZ.SAC.bp
# 20220205234904960
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220205234904960
# 20220205234904960.CI.NCH.BHZ.SAC.bp
# 20220206232447510
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220206232447510
# 20220206232447510.AZ.LVA2.BHZ.SAC.bp
# 20220206232447510.CI.PSR.BHZ.SAC.bp
# 20220206232447510.CI.RIO.BHZ.SAC.bp
# 20220207121028870
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220207121028870
# 20220207121028870.CI.LMR2.BHZ.SAC.bp
# 20220209014742470
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220209014742470
# 20220209014742470.CI.KRV3.BHZ.SAC.bp
# 20220209040551690
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220209040551690
# 20220209040551690.CI.CLC.BHZ.SAC.bp
# 20220209040551690.CI.CWC.BHZ.SAC.bp
# 20220209121834630
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220209121834630
# 20220209121834630.CI.IKP.BHZ.SAC.bp
# 20220209121834630.CI.YUH2.BHZ.SAC.bp
# 20220211121842170
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220211121842170
# 20220211121842170.CI.SRT.BHZ.SAC.bp
# 20220211141550450
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220211141550450
# 20220211141550450.CI.SRT.BHZ.SAC.bp
# 20220211142113660
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220211142113660
# 20220211142113660.CI.CCA.BHZ.SAC.bp
# 20220211232548160
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220211232548160
# 20220211232548160.CI.SLH.BHZ.SAC.bp

# %%
target_dir = "/home/youzhi/python-projects/sp-project/envelope"

# %%
# move all the ev files into a folder
data_sac = "/home/youzhi/python-projects/sp-project/SAC_for_readin"
num_files = 0
for path in os.listdir(data_sac):
    #print(path)
    if path.endswith("ini") != True:
        
        for file in os.listdir(os.path.join(data_sac, path)):
            #print(file)
            if file.endswith(".ev"):
                filepath = os.path.join(data_sac, path, file)
                shutil.copy(filepath, os.path.join(target_dir, file))
                print(filepath)
	    #some times if might count desktop.ini files
                num_files += 1
print(num_files)
# Out:
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220211141550450/20220211141550450.CI.SRT.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220116091814410/20220116091814410.BC.RMX.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220116091814410/20220116091814410.CI.ERR.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220116091814410/20220116091814410.CI.IMP.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220202100105740/20220202100105740.CI.FRK.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220202100105740/20220202100105740.CI.WWC.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220202070130500/20220202070130500.CI.FRK.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220211142113660/20220211142113660.CI.CCA.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220112021208390/20220112021208390.BC.RMX.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220112021208390/20220112021208390.AZ.LVA2.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220112021208390/20220112021208390.AZ.SMER.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220112002458770/20220112002458770.CI.HOL.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220113032108850/20220113032108850.CI.CSH.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220116124930000/20220116124930000.CI.CCA.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220116124930000/20220116124930000.CI.LMR2.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220116124930000/20220116124930000.CI.TEH.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220116124930000/20220116124930000.CI.SRT.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220116124930000/20220116124930000.CI.CCC.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220205074909660/20220205074909660.CI.YUH2.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220205074909660/20220205074909660.CI.HAY.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220115161902000/20220115161902000.CI.TEH.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220115161902000/20220115161902000.CI.FDR.BHZ.SAC.bp.ev
# /home/youzhi/python-projects/sp-project/SAC_for_readin/20220