# %%
def retrieveVariables(filename):
    variables = []
    with open(str(filename), 'rb') as file:
        variables = pickle.load(file)
    return variables

# %%
import os
import pickle
import matplotlib.pyplot as plt
import random

num = random.sample(range(1,101), 10)


os.getcwd()
# Out:
# '/home/youzhi/python-projects/sp-project/notebooks'

# %% [markdown]
# # Good signals

# %%
datadir = "/home/youzhi/python-projects/sp-project/good_readindata"


[envelop_signal, PmP_time, PmP_label, 
 PmP_dist, PmP_evdp, PmP_mag, PmP_stlo, 
 PmP_stla, PmP_evlo, PmP_evla, PmP_evid, 
 PmP_fname] = retrieveVariables(f"{datadir}/readindata")

# %%
for i in num:
    print(i)
    plt.plot(envelop_signal[i])
    plt.show()
# Out:
# 28
# 90
# 100
# 58
# 15
# 25
# 44
# 14
# 78
# 71

# %% [markdown]
# # Bad signals

# %%
datadir = "/home/youzhi/python-projects/sp-project/bad_readindata"


[envelop_signal, PmP_time, PmP_label, 
 PmP_dist, PmP_evdp, PmP_mag, PmP_stlo, 
 PmP_stla, PmP_evlo, PmP_evla, PmP_evid, 
 PmP_fname] = retrieveVariables(f"{datadir}/readindata")

for i in num:
    print(i)
    plt.plot(envelop_signal[i])
    plt.show()
# Out:
# 80
# 44
# 64
# 93
# 23
# 99
# 24
# 47
# 67
# 87
